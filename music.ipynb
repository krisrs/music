# %%
#Including the path for the package
import sys
sys.path.append('/home/santhana/packages/py27_packs')
sys.path.append('/home/santhana/packages/py27_packs/pyAudioAnalysis/data')
from pyAudioAnalysis import audioTrainTest as aT

# %%
#Training the SVM model to learn from the Raagas and song snippets
from pyAudioAnalysis import audioTrainTest as aT
aT.featureAndTrain(["/home/santhana/data/audio/aabheri/","/home/santhana/data/audio/kapi/","/home/santhana/data/audio/sankara/"], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "svm", "svmMusicRaaga3", True)

# %%
#Training a KNN model to learn from the Raagas and song snippets
from pyAudioAnalysis import audioTrainTest as aT
aT.featureAndTrain(["/home/santhana/data/audio/aabheri/","/home/santhana/data/audio/kapi/","/home/santhana/data/audio/sankara/"], 1.0, 1.0, aT.shortTermWindow, aT.shortTermStep, "knn", "knnMusicRaaga3", True)

# %%
#Classifying a New File using SVM
aT.fileClassification("/home/santhana/data/audio/test/wav/aishshri --- germaniyin_senthaen_sankarabharanam.wav", "/home/santhana/projects/audio_analysis/svmMusicRaaga3","svm")
# Out:
# (2.0,
#  array([ 0.17693034,  0.54870078,  0.27436888]),
#  ['aabheri', 'kapi', 'sankara'])

# %%
#Classifying a New File using SVM
aT.fileClassification("/home/santhana/data/audio/test/wav/radhakrishnan --- hey_paadal_ondru_kapi.wav", "/home/santhana/projects/audio_analysis/svmMusicRaaga3","svm")
# Out:
# (2.0,
#  array([ 0.24366924,  0.50473329,  0.25159747]),
#  ['aabheri', 'kapi', 'sankara'])

# %%
#Classifying a New File using SVM
aT.fileClassification("/home/santhana/data/audio/test/wav/swami --- rakkamma_kaiya_thattu_aabheri.wav", "/home/santhana/projects/audio_analysis/svmMusicRaaga3","svm")
# Out:
# (1.0,
#  array([ 0.52863696,  0.17338667,  0.29797637]),
#  ['aabheri', 'kapi', 'sankara'])

# %%
#Classifying a New File using SVM
aT.fileClassification("/home/santhana/data/audio/test/wav/raman_kadhai_kelungal.wav", "/home/santhana/projects/audio_analysis/svmMusicRaaga3","svm")
# Out:
# (2.0,
#  array([ 0.3371595,  0.3778476,  0.2849929]),
#  ['aabheri', 'kapi', 'sankara'])

# %%
#Classifying a New File using KNN
aT.fileClassification("/home/santhana/data/audio/test/wav/aishshri --- germaniyin_senthaen_sankarabharanam.wav", "/home/santhana/projects/audio_analysis/knnMusicRaaga3","knn")
# Out:
# (0,
#  array([ 0.33333333,  0.33333333,  0.33333333]),
#  ['aabheri', 'kapi', 'sankara'])

# %%
#Classifying a New File using KNN
aT.fileClassification("/home/santhana/data/audio/test/wav/radhakrishnan --- hey_paadal_ondru_kapi.wav", "/home/santhana/projects/audio_analysis/knnMusicRaaga3","knn")
# Out:
# (2,
#  array([ 0.        ,  0.33333333,  0.66666667]),
#  ['aabheri', 'kapi', 'sankara'])

# %%
#Classifying a New File using KNN
aT.fileClassification("/home/santhana/data/audio/test/wav/swami --- rakkamma_kaiya_thattu_aabheri.wav", "/home/santhana/projects/audio_analysis/knnMusicRaaga3","knn")
# Out:
# (1,
#  array([ 0.        ,  0.66666667,  0.33333333]),
#  ['aabheri', 'kapi', 'sankara'])

# %%
#Classifying a New File using KNN
aT.fileClassification("/home/santhana/data/audio/test/wav/rama_kadhai_kelungal.wav", "/home/santhana/projects/audio_analysis/knnMusicRaaga3","knn")
# Out:
# (-1, -1, -1)

# %%
from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import audioFeatureExtraction
import matplotlib.pyplot as plt
# Out:
# /home/santhana/software/anaconda3/envs/py27/lib/python2.7/site-packages/pydub/utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
from pyAudioAnalysis import audioVisualization as av
av.visualizeFeaturesFolder("/home/santhana/data/audio/stereo",'pca','none')

# %%
from pyAudioAnalysis import audioVisualization as av
av.visualizeFeaturesFolder("/home/santhana/data/audio/raga",'lda','none')

# %%
from pyAudioAnalysis import audioVisualization as av
av.visualizeFeaturesFolder("/home/santhana/data/audio/rama",'pca','none')
